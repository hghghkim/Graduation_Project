# %%
from keras import models, layers
from keras import Input
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers, initializers, regularizers, metrics
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import BatchNormalization, Conv3D, Activation, Dense, GlobalAveragePooling3D, MaxPooling3D, ZeroPadding3D, Add
from keras.optimizers import Adam 
import os
#import matplotlib.pyplot as plt
import numpy as np
import math

import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1,2"

# %%
train_x = np.load('/home/ckwwk/data/germination_data/old_germination_data.npy')

# %%
train_x.shape
# Out:
# (1536, 60, 60, 275, 1)

# %%
t1 = train_x[286:1536,:,:,:]
tt1 = train_x[0:286,:,:,:]

# %%
import pandas as pd

label_df = pd.read_csv("/home/ckwwk/data/germination_data/label/old_germination_label.csv")
label_df.head(5)
# Out:
#    label
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0

# %%
from keras.utils import to_categorical
train_y = label_df[286:1536]
train_y = to_categorical(train_y)

# %%
test_y = label_df[0:286]
test_y = to_categorical(test_y)

# %%
t1 = t1.astype('float32')
tt1 = tt1.astype('float32')

# %%
from keras.backend import tensorflow_backend as K
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
K.set_session(tf.Session(config=config))

# %%
input_tensor = Input(shape=(60, 60, 275,1), dtype='float32', name='input')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1023 22:26:59.904393 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# CNN 알고리즘으로 유명한 ResNet-50을 기반으로 2d가 아닌 3d layer로 변환한 모델이다.

def conv1_layer(x):    
    #x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv3D(64, (7, 7, 7), strides=2)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding3D(padding=(1,1,1))(x)
 
    return x   
 
    
def conv2_layer(x):         
    x = MaxPooling3D((2, 2, 2), 2)(x)     
 
    shortcut = x
 
    for i in range(3):
        if (i == 0):
            x = Conv3D(64, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(64, (3, 3,3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(256, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(256, (1, 1,1), strides=1, padding='valid')(shortcut)            
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            
            shortcut = x
 
        else:
            x = Conv3D(64, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(64, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(256, (1, 1,1 ), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x
 
 
 
def conv3_layer(x):        
    shortcut = x    
    
    for i in range(4):     
        if(i == 0):            
            x = Conv3D(128, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(128, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(512, (1, 1,1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)    
 
            shortcut = x              
        
        else:
            x = Conv3D(128, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(128, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x
 
 
 
def conv4_layer(x):
    shortcut = x        
  
    for i in range(6):     
        if(i == 0):            
            x = Conv3D(256, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(256, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(1024, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(1024, (1, 1, 1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
 
            shortcut = x               
        
        else:
            x = Conv3D(256, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(256, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(1024, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x
 
 
 
def conv5_layer(x):
    shortcut = x    
  
    for i in range(3):     
        if(i == 0):            
            x = Conv3D(512, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(512, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(2048, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(2048, (1, 1, 1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])  
            x = Activation('relu')(x)      
 
            shortcut = x               
        
        else:
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(512, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(2048, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)           
            
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)       
 
            shortcut = x                  
 
    return x

# %%
x = conv1_layer(input_tensor)
x = conv2_layer(x)
x = conv3_layer(x)
x = conv4_layer(x)
x = conv5_layer(x)
 
x = GlobalAveragePooling3D()(x)
output_tensor = Dense(2, activation='softmax')(x)
# Out:
# W1023 22:26:59.959473 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1023 22:26:59.961023 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1023 22:27:00.041488 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.

# %%
model = Model(input_tensor, output_tensor)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 60, 60, 275,  0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 27, 27, 135,  22016       input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 135,  256         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 27, 27, 135,  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding3d_1 (ZeroPadding3D (None, 29, 29, 137,  0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 14, 14, 68, 6 0           zero_padding3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 14, 14, 68, 6 4160        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 68, 6 256         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 14, 14, 68, 6 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 68, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 14, 14, 68, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 14, 14, 68, 2 16640       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 68, 2 1024        conv3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 68, 2 1024        conv3d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 68, 2 0           batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 68, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 14, 14, 68, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 68, 6 256         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 14, 14, 68, 6 110656      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 68, 6 256         conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 14, 14, 68, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 68, 2 1024        conv3d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 68, 2 0           batch_normalization_8[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 68, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 14, 14, 68, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 68, 6 256         conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 14, 14, 68, 6 110656      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 68, 6 256         conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 68, 6 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 14, 14, 68, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 68, 2 1024        conv3d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 68, 2 0           batch_normalization_11[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 68, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 7, 7, 34, 128 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 34, 128 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 7, 7, 34, 128 442496      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 34, 128 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 7, 7, 34, 512 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 7, 7, 34, 512 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 34, 512 2048        conv3d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 34, 512 2048        conv3d_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 34, 512 0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 34, 512 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 7, 7, 34, 128 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 34, 128 512         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 7, 7, 34, 128 442496      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 34, 128 512         conv3d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 7, 7, 34, 512 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 34, 512 2048        conv3d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 34, 512 0           batch_normalization_18[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 34, 512 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 7, 7, 34, 128 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 34, 128 512         conv3d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 7, 7, 34, 128 442496      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, 7, 34, 128 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 7, 7, 34, 512 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 34, 512 2048        conv3d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 34, 512 0           batch_normalization_21[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, 7, 34, 512 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 7, 7, 34, 128 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 34, 128 512         conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 7, 7, 34, 128 442496      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 34, 128 512         conv3d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 7, 7, 34, 128 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 7, 7, 34, 512 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 34, 512 2048        conv3d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 34, 512 0           batch_normalization_24[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, 7, 34, 512 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 4, 4, 17, 256 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 4, 4, 17, 102 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_28[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 17, 102 0           batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 17, 102 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 4, 4, 17, 256 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_31[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 17, 102 0           batch_normalization_31[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 17, 102 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 4, 4, 17, 256 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_34[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 17, 102 0           batch_normalization_34[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 17, 102 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 4, 4, 17, 256 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_37[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 17, 102 0           batch_normalization_37[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 17, 102 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 4, 4, 17, 256 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_40[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 17, 102 0           batch_normalization_40[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 4, 4, 17, 102 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 4, 4, 17, 256 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 4, 4, 17, 256 1769728     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 17, 256 1024        conv3d_42[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 4, 4, 17, 256 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 4, 4, 17, 102 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 17, 102 4096        conv3d_43[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 17, 102 0           batch_normalization_43[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 17, 102 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 2, 2, 9, 512) 524800      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 2, 2, 9, 512) 7078400     activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 2, 2, 9, 2048 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 2, 2, 9, 2048 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 9, 2048 8192        conv3d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 9, 2048 8192        conv3d_47[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 9, 2048 0           batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 2, 2, 9, 2048 0           add_14[0][0]
# __________________________________________________________________________________________________
# conv3d_48 (Conv3D)              (None, 2, 2, 9, 512) 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv3d_49 (Conv3D)              (None, 2, 2, 9, 512) 7078400     activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_49[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 2, 2, 9, 2048 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 2, 2, 9, 2048 8192        conv3d_50[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 9, 2048 0           batch_normalization_50[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 2, 2, 9, 2048 0           add_15[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 2, 2, 9, 512) 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_51[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 2, 2, 9, 512) 7078400     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 2, 2, 9, 512) 2048        conv3d_52[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 2, 2, 9, 512) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv3d_53 (Conv3D)              (None, 2, 2, 9, 2048 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 2, 2, 9, 2048 8192        conv3d_53[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 2, 2, 9, 2048 0           batch_normalization_53[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 2, 2, 9, 2048 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_1 (Glo (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            4098        global_average_pooling3d_1[0][0]
# ==================================================================================================
# Total params: 46,238,850
# Trainable params: 46,185,730
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from keras.utils import multi_gpu_model
model = multi_gpu_model(model,gpus=2)
# Out:
# W1023 22:27:05.565401 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.

# %%
adam = Adam(lr=0.0001, decay=1e-06)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
# Out:
# W1023 22:27:17.955708 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
filepath = "raw_resnet.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
tb = keras.callbacks.TensorBoard(log_dir='raw_resnet',histogram_freq=1,)
callbacks_list = [checkpoint,tb]

# %%
import timeit
start = timeit.default_timer()

history = model.fit(x=t1, y=train_y , batch_size=32, epochs=200,validation_split=0.1 ,callbacks=callbacks_list)

stop = timeit.default_timer()
print(stop - start)
# Out:
# W1023 22:27:19.265018 140081080248128 deprecation.py:323] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1125 samples, validate on 125 samples
# W1023 22:27:47.054144 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1120: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W1023 22:27:47.430632 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W1023 22:27:47.440688 140081080248128 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/200
# 1125/1125 [==============================] - 65s 58ms/step - loss: 0.7948 - acc: 0.5191 - val_loss: 5.6736 - val_acc: 0.6480
#
# Epoch 00001: val_acc improved from -inf to 0.64800, saving model to raw_resnet.hdf5
# Epoch 2/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.7290 - acc: 0.5778 - val_loss: 1.0798 - val_acc: 0.6480
#
# Epoch 00002: val_acc did not improve from 0.64800
# Epoch 3/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.7573 - acc: 0.5742 - val_loss: 0.8689 - val_acc: 0.6480
#
# Epoch 00003: val_acc did not improve from 0.64800
# Epoch 4/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6853 - acc: 0.5893 - val_loss: 3.7971 - val_acc: 0.3520
#
# Epoch 00004: val_acc did not improve from 0.64800
# Epoch 5/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.6979 - acc: 0.5929 - val_loss: 2.2905 - val_acc: 0.6480
#
# Epoch 00005: val_acc did not improve from 0.64800
# Epoch 6/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6700 - acc: 0.6213 - val_loss: 1.9967 - val_acc: 0.6480
#
# Epoch 00006: val_acc did not improve from 0.64800
# Epoch 7/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6226 - acc: 0.6649 - val_loss: 6.0174 - val_acc: 0.3520
#
# Epoch 00007: val_acc did not improve from 0.64800
# Epoch 8/200
# 1125/1125 [==============================] - 32s 29ms/step - loss: 0.6910 - acc: 0.6062 - val_loss: 2.2605 - val_acc: 0.3520
#
# Epoch 00008: val_acc did not improve from 0.64800
# Epoch 9/200
# 1125/1125 [==============================] - 32s 28ms/step - loss: 0.6152 - acc: 0.6711 - val_loss: 6.4596 - val_acc: 0.3520
#
# Epoch 00009: val_acc did not improve from 0.64800
# Epoch 10/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6728 - acc: 0.6249 - val_loss: 2.7143 - val_acc: 0.6480
#
# Epoch 00010: val_acc did not improve from 0.64800
# Epoch 11/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6171 - acc: 0.6738 - val_loss: 0.9414 - val_acc: 0.6480
#
# Epoch 00011: val_acc did not improve from 0.64800
# Epoch 12/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6200 - acc: 0.6747 - val_loss: 0.7225 - val_acc: 0.6320
#
# Epoch 00012: val_acc did not improve from 0.64800
# Epoch 13/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.6036 - acc: 0.6942 - val_loss: 2.0574 - val_acc: 0.3600
#
# Epoch 00013: val_acc did not improve from 0.64800
# Epoch 14/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.5764 - acc: 0.6916 - val_loss: 1.9843 - val_acc: 0.6480
#
# Epoch 00014: val_acc did not improve from 0.64800
# Epoch 15/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.5432 - acc: 0.7200 - val_loss: 0.8608 - val_acc: 0.6400
#
# Epoch 00015: val_acc did not improve from 0.64800
# Epoch 16/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5687 - acc: 0.7084 - val_loss: 3.2500 - val_acc: 0.3520
#
# Epoch 00016: val_acc did not improve from 0.64800
# Epoch 17/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5271 - acc: 0.7378 - val_loss: 1.0569 - val_acc: 0.4320
#
# Epoch 00017: val_acc did not improve from 0.64800
# Epoch 18/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4985 - acc: 0.7511 - val_loss: 0.8668 - val_acc: 0.4880
#
# Epoch 00018: val_acc did not improve from 0.64800
# Epoch 19/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5788 - acc: 0.7102 - val_loss: 4.6932 - val_acc: 0.3520
#
# Epoch 00019: val_acc did not improve from 0.64800
# Epoch 20/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5050 - acc: 0.7351 - val_loss: 1.4729 - val_acc: 0.3600
#
# Epoch 00020: val_acc did not improve from 0.64800
# Epoch 21/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4557 - acc: 0.7849 - val_loss: 3.6481 - val_acc: 0.6480
#
# Epoch 00021: val_acc did not improve from 0.64800
# Epoch 22/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5226 - acc: 0.7467 - val_loss: 1.0537 - val_acc: 0.4400
#
# Epoch 00022: val_acc did not improve from 0.64800
# Epoch 23/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4680 - acc: 0.7858 - val_loss: 4.1131 - val_acc: 0.6480
#
# Epoch 00023: val_acc did not improve from 0.64800
# Epoch 24/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.4514 - acc: 0.7787 - val_loss: 1.1496 - val_acc: 0.4480
#
# Epoch 00024: val_acc did not improve from 0.64800
# Epoch 25/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4758 - acc: 0.7636 - val_loss: 1.7245 - val_acc: 0.6480
#
# Epoch 00025: val_acc did not improve from 0.64800
# Epoch 26/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.5184 - acc: 0.7493 - val_loss: 2.2497 - val_acc: 0.6480
#
# Epoch 00026: val_acc did not improve from 0.64800
# Epoch 27/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4904 - acc: 0.7573 - val_loss: 1.4745 - val_acc: 0.3600
#
# Epoch 00027: val_acc did not improve from 0.64800
# Epoch 28/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5680 - acc: 0.6960 - val_loss: 0.8130 - val_acc: 0.6560
#
# Epoch 00028: val_acc improved from 0.64800 to 0.65600, saving model to raw_resnet.hdf5
# Epoch 29/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4701 - acc: 0.7769 - val_loss: 1.2891 - val_acc: 0.6400
#
# Epoch 00029: val_acc did not improve from 0.65600
# Epoch 30/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5487 - acc: 0.7147 - val_loss: 0.6783 - val_acc: 0.6160
#
# Epoch 00030: val_acc did not improve from 0.65600
# Epoch 31/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4640 - acc: 0.7627 - val_loss: 0.8947 - val_acc: 0.6240
#
# Epoch 00031: val_acc did not improve from 0.65600
# Epoch 32/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5748 - acc: 0.7147 - val_loss: 1.4244 - val_acc: 0.6480
#
# Epoch 00032: val_acc did not improve from 0.65600
# Epoch 33/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4244 - acc: 0.8036 - val_loss: 0.7102 - val_acc: 0.5840
#
# Epoch 00033: val_acc did not improve from 0.65600
# Epoch 34/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4473 - acc: 0.7973 - val_loss: 0.8823 - val_acc: 0.6320
#
# Epoch 00034: val_acc did not improve from 0.65600
# Epoch 35/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.4536 - acc: 0.7609 - val_loss: 2.5331 - val_acc: 0.3520
#
# Epoch 00035: val_acc did not improve from 0.65600
# Epoch 36/200
# 1125/1125 [==============================] - 30s 26ms/step - loss: 0.3864 - acc: 0.8133 - val_loss: 1.3624 - val_acc: 0.6480
#
# Epoch 00036: val_acc did not improve from 0.65600
# Epoch 37/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4640 - acc: 0.7929 - val_loss: 0.7590 - val_acc: 0.5120
#
# Epoch 00037: val_acc did not improve from 0.65600
# Epoch 38/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4544 - acc: 0.7769 - val_loss: 0.7771 - val_acc: 0.6240
#
# Epoch 00038: val_acc did not improve from 0.65600
# Epoch 39/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4239 - acc: 0.8009 - val_loss: 1.2423 - val_acc: 0.6560
#
# Epoch 00039: val_acc improved from 0.65600 to 0.65600, saving model to raw_resnet.hdf5
# Epoch 40/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.3601 - acc: 0.8338 - val_loss: 1.8087 - val_acc: 0.6480
#
# Epoch 00040: val_acc did not improve from 0.65600
# Epoch 41/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4752 - acc: 0.7698 - val_loss: 2.5795 - val_acc: 0.6480
#
# Epoch 00041: val_acc did not improve from 0.65600
# Epoch 42/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.4338 - acc: 0.8009 - val_loss: 3.0252 - val_acc: 0.6480
#
# Epoch 00042: val_acc did not improve from 0.65600
# Epoch 43/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.3823 - acc: 0.8409 - val_loss: 1.0572 - val_acc: 0.5840
#
# Epoch 00043: val_acc did not improve from 0.65600
# Epoch 44/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.3265 - acc: 0.8604 - val_loss: 1.1390 - val_acc: 0.6080
#
# Epoch 00044: val_acc did not improve from 0.65600
# Epoch 45/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.3304 - acc: 0.8587 - val_loss: 1.9634 - val_acc: 0.6480
#
# Epoch 00045: val_acc did not improve from 0.65600
# Epoch 46/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.3775 - acc: 0.8338 - val_loss: 1.8530 - val_acc: 0.3520
#
# Epoch 00046: val_acc did not improve from 0.65600
# Epoch 47/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2845 - acc: 0.8853 - val_loss: 1.3893 - val_acc: 0.5120
#
# Epoch 00047: val_acc did not improve from 0.65600
# Epoch 48/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.2962 - acc: 0.8676 - val_loss: 1.2294 - val_acc: 0.5120
#
# Epoch 00048: val_acc did not improve from 0.65600
# Epoch 49/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3215 - acc: 0.8587 - val_loss: 1.6858 - val_acc: 0.6480
#
# Epoch 00049: val_acc did not improve from 0.65600
# Epoch 50/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.2900 - acc: 0.8631 - val_loss: 1.1111 - val_acc: 0.6480
#
# Epoch 00050: val_acc did not improve from 0.65600
# Epoch 51/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3370 - acc: 0.8409 - val_loss: 3.0016 - val_acc: 0.6480
#
# Epoch 00051: val_acc did not improve from 0.65600
# Epoch 52/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.3774 - acc: 0.8284 - val_loss: 4.8344 - val_acc: 0.6480
#
# Epoch 00052: val_acc did not improve from 0.65600
# Epoch 53/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3698 - acc: 0.8400 - val_loss: 2.6183 - val_acc: 0.6480
#
# Epoch 00053: val_acc did not improve from 0.65600
# Epoch 54/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.3134 - acc: 0.8649 - val_loss: 1.7050 - val_acc: 0.4240
#
# Epoch 00054: val_acc did not improve from 0.65600
# Epoch 55/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4151 - acc: 0.7991 - val_loss: 4.9084 - val_acc: 0.6480
#
# Epoch 00055: val_acc did not improve from 0.65600
# Epoch 56/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.4779 - acc: 0.7653 - val_loss: 2.6733 - val_acc: 0.6480
#
# Epoch 00056: val_acc did not improve from 0.65600
# Epoch 57/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.5004 - acc: 0.7298 - val_loss: 2.6505 - val_acc: 0.6480
#
# Epoch 00057: val_acc did not improve from 0.65600
# Epoch 58/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4349 - acc: 0.7947 - val_loss: 0.9778 - val_acc: 0.5120
#
# Epoch 00058: val_acc did not improve from 0.65600
# Epoch 59/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3523 - acc: 0.8391 - val_loss: 2.4349 - val_acc: 0.6480
#
# Epoch 00059: val_acc did not improve from 0.65600
# Epoch 60/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.4674 - acc: 0.7609 - val_loss: 3.6356 - val_acc: 0.6480
#
# Epoch 00060: val_acc did not improve from 0.65600
# Epoch 61/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4978 - acc: 0.7573 - val_loss: 1.9360 - val_acc: 0.6480
#
# Epoch 00061: val_acc did not improve from 0.65600
# Epoch 62/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.4071 - acc: 0.8107 - val_loss: 0.9782 - val_acc: 0.6240
#
# Epoch 00062: val_acc did not improve from 0.65600
# Epoch 63/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.4051 - acc: 0.8151 - val_loss: 1.6095 - val_acc: 0.6480
#
# Epoch 00063: val_acc did not improve from 0.65600
# Epoch 64/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3614 - acc: 0.8169 - val_loss: 0.9920 - val_acc: 0.5840
#
# Epoch 00064: val_acc did not improve from 0.65600
# Epoch 65/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.4064 - acc: 0.8080 - val_loss: 1.9541 - val_acc: 0.6400
#
# Epoch 00065: val_acc did not improve from 0.65600
# Epoch 66/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.4353 - acc: 0.7929 - val_loss: 0.7734 - val_acc: 0.6080
#
# Epoch 00066: val_acc did not improve from 0.65600
# Epoch 67/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.3514 - acc: 0.8373 - val_loss: 0.8137 - val_acc: 0.6160
#
# Epoch 00067: val_acc did not improve from 0.65600
# Epoch 68/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.3493 - acc: 0.8471 - val_loss: 0.8158 - val_acc: 0.6080
#
# Epoch 00068: val_acc did not improve from 0.65600
# Epoch 69/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.2732 - acc: 0.8791 - val_loss: 1.1550 - val_acc: 0.5760
#
# Epoch 00069: val_acc did not improve from 0.65600
# Epoch 70/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2508 - acc: 0.8907 - val_loss: 2.1549 - val_acc: 0.4240
#
# Epoch 00070: val_acc did not improve from 0.65600
# Epoch 71/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2386 - acc: 0.8862 - val_loss: 1.2616 - val_acc: 0.5920
#
# Epoch 00071: val_acc did not improve from 0.65600
# Epoch 72/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2636 - acc: 0.8738 - val_loss: 1.9603 - val_acc: 0.6400
#
# Epoch 00072: val_acc did not improve from 0.65600
# Epoch 73/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.2880 - acc: 0.8836 - val_loss: 1.6952 - val_acc: 0.6320
#
# Epoch 00073: val_acc did not improve from 0.65600
# Epoch 74/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.2823 - acc: 0.8738 - val_loss: 1.4098 - val_acc: 0.4400
#
# Epoch 00074: val_acc did not improve from 0.65600
# Epoch 75/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2404 - acc: 0.8978 - val_loss: 1.0265 - val_acc: 0.5840
#
# Epoch 00075: val_acc did not improve from 0.65600
# Epoch 76/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1803 - acc: 0.9244 - val_loss: 1.6438 - val_acc: 0.6320
#
# Epoch 00076: val_acc did not improve from 0.65600
# Epoch 77/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1893 - acc: 0.9236 - val_loss: 1.1244 - val_acc: 0.6080
#
# Epoch 00077: val_acc did not improve from 0.65600
# Epoch 78/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2490 - acc: 0.8933 - val_loss: 1.5931 - val_acc: 0.6320
#
# Epoch 00078: val_acc did not improve from 0.65600
# Epoch 79/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1463 - acc: 0.9431 - val_loss: 2.0421 - val_acc: 0.6240
#
# Epoch 00079: val_acc did not improve from 0.65600
# Epoch 80/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1729 - acc: 0.9351 - val_loss: 1.3598 - val_acc: 0.5840
#
# Epoch 00080: val_acc did not improve from 0.65600
# Epoch 81/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2442 - acc: 0.8969 - val_loss: 1.8908 - val_acc: 0.4640
#
# Epoch 00081: val_acc did not improve from 0.65600
# Epoch 82/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2337 - acc: 0.9013 - val_loss: 1.4697 - val_acc: 0.6320
#
# Epoch 00082: val_acc did not improve from 0.65600
# Epoch 83/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.1997 - acc: 0.9200 - val_loss: 1.1418 - val_acc: 0.4800
#
# Epoch 00083: val_acc did not improve from 0.65600
# Epoch 84/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1784 - acc: 0.9200 - val_loss: 1.4737 - val_acc: 0.6160
#
# Epoch 00084: val_acc did not improve from 0.65600
# Epoch 85/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1784 - acc: 0.9280 - val_loss: 1.7933 - val_acc: 0.4560
#
# Epoch 00085: val_acc did not improve from 0.65600
# Epoch 86/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2502 - acc: 0.8996 - val_loss: 3.3165 - val_acc: 0.6480
#
# Epoch 00086: val_acc did not improve from 0.65600
# Epoch 87/200
# 1125/1125 [==============================] - 30s 26ms/step - loss: 0.1481 - acc: 0.9467 - val_loss: 1.3220 - val_acc: 0.6000
#
# Epoch 00087: val_acc did not improve from 0.65600
# Epoch 88/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1589 - acc: 0.9387 - val_loss: 1.0643 - val_acc: 0.5680
#
# Epoch 00088: val_acc did not improve from 0.65600
# Epoch 89/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1296 - acc: 0.9511 - val_loss: 1.7738 - val_acc: 0.5680
#
# Epoch 00089: val_acc did not improve from 0.65600
# Epoch 90/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1307 - acc: 0.9493 - val_loss: 1.3934 - val_acc: 0.5280
#
# Epoch 00090: val_acc did not improve from 0.65600
# Epoch 91/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0986 - acc: 0.9573 - val_loss: 2.0505 - val_acc: 0.4960
#
# Epoch 00091: val_acc did not improve from 0.65600
# Epoch 92/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.0578 - acc: 0.9769 - val_loss: 1.7056 - val_acc: 0.4720
#
# Epoch 00092: val_acc did not improve from 0.65600
# Epoch 93/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.0830 - acc: 0.9680 - val_loss: 2.2539 - val_acc: 0.5920
#
# Epoch 00093: val_acc did not improve from 0.65600
# Epoch 94/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0750 - acc: 0.9707 - val_loss: 1.3150 - val_acc: 0.5280
#
# Epoch 00094: val_acc did not improve from 0.65600
# Epoch 95/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1755 - acc: 0.9289 - val_loss: 2.8261 - val_acc: 0.6400
#
# Epoch 00095: val_acc did not improve from 0.65600
# Epoch 96/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1730 - acc: 0.9360 - val_loss: 1.2196 - val_acc: 0.5200
#
# Epoch 00096: val_acc did not improve from 0.65600
# Epoch 97/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1377 - acc: 0.9476 - val_loss: 1.7036 - val_acc: 0.4880
#
# Epoch 00097: val_acc did not improve from 0.65600
# Epoch 98/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0996 - acc: 0.9609 - val_loss: 2.4060 - val_acc: 0.6080
#
# Epoch 00098: val_acc did not improve from 0.65600
# Epoch 99/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1682 - acc: 0.9271 - val_loss: 1.6898 - val_acc: 0.6480
#
# Epoch 00099: val_acc did not improve from 0.65600
# Epoch 100/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1996 - acc: 0.9200 - val_loss: 1.8945 - val_acc: 0.6480
#
# Epoch 00100: val_acc did not improve from 0.65600
# Epoch 101/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1237 - acc: 0.9511 - val_loss: 1.1131 - val_acc: 0.4800
#
# Epoch 00101: val_acc did not improve from 0.65600
# Epoch 102/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1320 - acc: 0.9520 - val_loss: 1.5421 - val_acc: 0.5520
#
# Epoch 00102: val_acc did not improve from 0.65600
# Epoch 103/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0832 - acc: 0.9680 - val_loss: 1.5509 - val_acc: 0.5360
#
# Epoch 00103: val_acc did not improve from 0.65600
# Epoch 104/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1266 - acc: 0.9440 - val_loss: 1.5846 - val_acc: 0.4480
#
# Epoch 00104: val_acc did not improve from 0.65600
# Epoch 105/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.1008 - acc: 0.9609 - val_loss: 1.5413 - val_acc: 0.5840
#
# Epoch 00105: val_acc did not improve from 0.65600
# Epoch 106/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0420 - acc: 0.9849 - val_loss: 1.7913 - val_acc: 0.5280
#
# Epoch 00106: val_acc did not improve from 0.65600
# Epoch 107/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0354 - acc: 0.9867 - val_loss: 2.2295 - val_acc: 0.5040
#
# Epoch 00107: val_acc did not improve from 0.65600
# Epoch 108/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0564 - acc: 0.9804 - val_loss: 1.7923 - val_acc: 0.4560
#
# Epoch 00108: val_acc did not improve from 0.65600
# Epoch 109/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0624 - acc: 0.9760 - val_loss: 1.9133 - val_acc: 0.4800
#
# Epoch 00109: val_acc did not improve from 0.65600
# Epoch 110/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0388 - acc: 0.9840 - val_loss: 1.8120 - val_acc: 0.4400
#
# Epoch 00110: val_acc did not improve from 0.65600
# Epoch 111/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1000 - acc: 0.9636 - val_loss: 2.2806 - val_acc: 0.6160
#
# Epoch 00111: val_acc did not improve from 0.65600
# Epoch 112/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1033 - acc: 0.9556 - val_loss: 1.9348 - val_acc: 0.6560
#
# Epoch 00112: val_acc improved from 0.65600 to 0.65600, saving model to raw_resnet.hdf5
# Epoch 113/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2203 - acc: 0.9058 - val_loss: 1.5482 - val_acc: 0.4240
#
# Epoch 00113: val_acc did not improve from 0.65600
# Epoch 114/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1985 - acc: 0.9289 - val_loss: 1.2921 - val_acc: 0.6080
#
# Epoch 00114: val_acc did not improve from 0.65600
# Epoch 115/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.2081 - acc: 0.9182 - val_loss: 1.5187 - val_acc: 0.6160
#
# Epoch 00115: val_acc did not improve from 0.65600
# Epoch 116/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.1579 - acc: 0.9404 - val_loss: 1.8087 - val_acc: 0.4560
#
# Epoch 00116: val_acc did not improve from 0.65600
# Epoch 117/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1551 - acc: 0.9458 - val_loss: 1.7573 - val_acc: 0.6400
#
# Epoch 00117: val_acc did not improve from 0.65600
# Epoch 118/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1657 - acc: 0.9307 - val_loss: 1.1181 - val_acc: 0.5520
#
# Epoch 00118: val_acc did not improve from 0.65600
# Epoch 119/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1470 - acc: 0.9467 - val_loss: 1.1382 - val_acc: 0.5200
#
# Epoch 00119: val_acc did not improve from 0.65600
# Epoch 120/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0811 - acc: 0.9671 - val_loss: 1.2367 - val_acc: 0.5040
#
# Epoch 00120: val_acc did not improve from 0.65600
# Epoch 121/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1280 - acc: 0.9582 - val_loss: 1.5868 - val_acc: 0.4720
#
# Epoch 00121: val_acc did not improve from 0.65600
# Epoch 122/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0490 - acc: 0.9858 - val_loss: 2.2598 - val_acc: 0.4720
#
# Epoch 00122: val_acc did not improve from 0.65600
# Epoch 123/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0514 - acc: 0.9796 - val_loss: 1.6756 - val_acc: 0.5600
#
# Epoch 00123: val_acc did not improve from 0.65600
# Epoch 124/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0954 - acc: 0.9627 - val_loss: 2.1128 - val_acc: 0.5920
#
# Epoch 00124: val_acc did not improve from 0.65600
# Epoch 125/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0357 - acc: 0.9902 - val_loss: 1.8342 - val_acc: 0.4880
#
# Epoch 00125: val_acc did not improve from 0.65600
# Epoch 126/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0117 - acc: 0.9991 - val_loss: 1.9423 - val_acc: 0.4880
#
# Epoch 00126: val_acc did not improve from 0.65600
# Epoch 127/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1327 - acc: 0.9440 - val_loss: 1.9192 - val_acc: 0.6240
#
# Epoch 00127: val_acc did not improve from 0.65600
# Epoch 128/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1592 - acc: 0.9467 - val_loss: 5.2122 - val_acc: 0.6480
#
# Epoch 00128: val_acc did not improve from 0.65600
# Epoch 129/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1427 - acc: 0.9440 - val_loss: 1.4410 - val_acc: 0.4240
#
# Epoch 00129: val_acc did not improve from 0.65600
# Epoch 130/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0534 - acc: 0.9813 - val_loss: 1.5030 - val_acc: 0.4880
#
# Epoch 00130: val_acc did not improve from 0.65600
# Epoch 131/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0479 - acc: 0.9831 - val_loss: 2.2135 - val_acc: 0.4720
#
# Epoch 00131: val_acc did not improve from 0.65600
# Epoch 132/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.0793 - acc: 0.9698 - val_loss: 1.4752 - val_acc: 0.4640
#
# Epoch 00132: val_acc did not improve from 0.65600
# Epoch 133/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.1238 - acc: 0.9484 - val_loss: 4.0189 - val_acc: 0.6480
#
# Epoch 00133: val_acc did not improve from 0.65600
# Epoch 134/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1974 - acc: 0.9289 - val_loss: 2.4763 - val_acc: 0.6320
#
# Epoch 00134: val_acc did not improve from 0.65600
# Epoch 135/200
# 1125/1125 [==============================] - 30s 26ms/step - loss: 0.0905 - acc: 0.9671 - val_loss: 3.3443 - val_acc: 0.3440
#
# Epoch 00135: val_acc did not improve from 0.65600
# Epoch 136/200
# 1125/1125 [==============================] - 29s 26ms/step - loss: 0.0679 - acc: 0.9787 - val_loss: 2.4678 - val_acc: 0.3920
#
# Epoch 00136: val_acc did not improve from 0.65600
# Epoch 137/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0854 - acc: 0.9689 - val_loss: 1.2675 - val_acc: 0.5200
#
# Epoch 00137: val_acc did not improve from 0.65600
# Epoch 138/200
# 1125/1125 [==============================] - 28s 24ms/step - loss: 0.0970 - acc: 0.9609 - val_loss: 1.2016 - val_acc: 0.5920
#
# Epoch 00138: val_acc did not improve from 0.65600
# Epoch 139/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1557 - acc: 0.9413 - val_loss: 1.3298 - val_acc: 0.5040
#
# Epoch 00139: val_acc did not improve from 0.65600
# Epoch 140/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0835 - acc: 0.9707 - val_loss: 3.2619 - val_acc: 0.6480
#
# Epoch 00140: val_acc did not improve from 0.65600
# Epoch 141/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1344 - acc: 0.9449 - val_loss: 5.4674 - val_acc: 0.6480
#
# Epoch 00141: val_acc did not improve from 0.65600
# Epoch 142/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1357 - acc: 0.9449 - val_loss: 4.3543 - val_acc: 0.6480
#
# Epoch 00142: val_acc did not improve from 0.65600
# Epoch 143/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1451 - acc: 0.9529 - val_loss: 2.6507 - val_acc: 0.3600
#
# Epoch 00143: val_acc did not improve from 0.65600
# Epoch 144/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1260 - acc: 0.9547 - val_loss: 1.3116 - val_acc: 0.5360
#
# Epoch 00144: val_acc did not improve from 0.65600
# Epoch 145/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1443 - acc: 0.9404 - val_loss: 1.3274 - val_acc: 0.5760
#
# Epoch 00145: val_acc did not improve from 0.65600
# Epoch 146/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1046 - acc: 0.9591 - val_loss: 1.0444 - val_acc: 0.5520
#
# Epoch 00146: val_acc did not improve from 0.65600
# Epoch 147/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0663 - acc: 0.9778 - val_loss: 1.5020 - val_acc: 0.5520
#
# Epoch 00147: val_acc did not improve from 0.65600
# Epoch 148/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0924 - acc: 0.9707 - val_loss: 2.6284 - val_acc: 0.4640
#
# Epoch 00148: val_acc did not improve from 0.65600
# Epoch 149/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0410 - acc: 0.9876 - val_loss: 1.6031 - val_acc: 0.5440
#
# Epoch 00149: val_acc did not improve from 0.65600
# Epoch 150/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1395 - acc: 0.9547 - val_loss: 1.2583 - val_acc: 0.4880
#
# Epoch 00150: val_acc did not improve from 0.65600
# Epoch 151/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1504 - acc: 0.9431 - val_loss: 1.1389 - val_acc: 0.5040
#
# Epoch 00151: val_acc did not improve from 0.65600
# Epoch 152/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1471 - acc: 0.9511 - val_loss: 1.2196 - val_acc: 0.5760
#
# Epoch 00152: val_acc did not improve from 0.65600
# Epoch 153/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1012 - acc: 0.9600 - val_loss: 1.3510 - val_acc: 0.5760
#
# Epoch 00153: val_acc did not improve from 0.65600
# Epoch 154/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0679 - acc: 0.9751 - val_loss: 1.7985 - val_acc: 0.5280
#
# Epoch 00154: val_acc did not improve from 0.65600
# Epoch 155/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0840 - acc: 0.9689 - val_loss: 1.6662 - val_acc: 0.6320
#
# Epoch 00155: val_acc did not improve from 0.65600
# Epoch 156/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0626 - acc: 0.9769 - val_loss: 2.8004 - val_acc: 0.6400
#
# Epoch 00156: val_acc did not improve from 0.65600
# Epoch 157/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0774 - acc: 0.9689 - val_loss: 2.0356 - val_acc: 0.6160
#
# Epoch 00157: val_acc did not improve from 0.65600
# Epoch 158/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.1038 - acc: 0.9582 - val_loss: 1.5029 - val_acc: 0.4800
#
# Epoch 00158: val_acc did not improve from 0.65600
# Epoch 159/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0377 - acc: 0.9884 - val_loss: 1.4525 - val_acc: 0.6000
#
# Epoch 00159: val_acc did not improve from 0.65600
# Epoch 160/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0276 - acc: 0.9911 - val_loss: 1.9290 - val_acc: 0.5280
#
# Epoch 00160: val_acc did not improve from 0.65600
# Epoch 161/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0225 - acc: 0.9902 - val_loss: 2.2263 - val_acc: 0.5920
#
# Epoch 00161: val_acc did not improve from 0.65600
# Epoch 162/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0523 - acc: 0.9831 - val_loss: 2.2559 - val_acc: 0.5440
#
# Epoch 00162: val_acc did not improve from 0.65600
# Epoch 163/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0356 - acc: 0.9858 - val_loss: 1.2094 - val_acc: 0.5040
#
# Epoch 00163: val_acc did not improve from 0.65600
# Epoch 164/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.3012 - acc: 0.8889 - val_loss: 5.6590 - val_acc: 0.6480
#
# Epoch 00164: val_acc did not improve from 0.65600
# Epoch 165/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.1674 - acc: 0.9253 - val_loss: 1.3075 - val_acc: 0.5440
#
# Epoch 00165: val_acc did not improve from 0.65600
# Epoch 166/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1196 - acc: 0.9538 - val_loss: 2.4908 - val_acc: 0.4240
#
# Epoch 00166: val_acc did not improve from 0.65600
# Epoch 167/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0862 - acc: 0.9662 - val_loss: 1.4223 - val_acc: 0.4960
#
# Epoch 00167: val_acc did not improve from 0.65600
# Epoch 168/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0934 - acc: 0.9636 - val_loss: 1.2553 - val_acc: 0.5280
#
# Epoch 00168: val_acc did not improve from 0.65600
# Epoch 169/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0491 - acc: 0.9840 - val_loss: 1.4210 - val_acc: 0.5840
#
# Epoch 00169: val_acc did not improve from 0.65600
# Epoch 170/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0803 - acc: 0.9724 - val_loss: 1.7713 - val_acc: 0.5040
#
# Epoch 00170: val_acc did not improve from 0.65600
# Epoch 171/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0579 - acc: 0.9804 - val_loss: 1.8017 - val_acc: 0.4960
#
# Epoch 00171: val_acc did not improve from 0.65600
# Epoch 172/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0425 - acc: 0.9858 - val_loss: 1.8642 - val_acc: 0.5920
#
# Epoch 00172: val_acc did not improve from 0.65600
# Epoch 173/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0277 - acc: 0.9920 - val_loss: 1.6257 - val_acc: 0.5440
#
# Epoch 00173: val_acc did not improve from 0.65600
# Epoch 174/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0190 - acc: 0.9929 - val_loss: 2.1843 - val_acc: 0.4640
#
# Epoch 00174: val_acc did not improve from 0.65600
# Epoch 175/200
# 1125/1125 [==============================] - 27s 24ms/step - loss: 0.0304 - acc: 0.9902 - val_loss: 1.7741 - val_acc: 0.5280
#
# Epoch 00175: val_acc did not improve from 0.65600
# Epoch 176/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1410 - acc: 0.9573 - val_loss: 2.9679 - val_acc: 0.6400
#
# Epoch 00176: val_acc did not improve from 0.65600
# Epoch 177/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1185 - acc: 0.9564 - val_loss: 1.3202 - val_acc: 0.5520
#
# Epoch 00177: val_acc did not improve from 0.65600
# Epoch 178/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1131 - acc: 0.9529 - val_loss: 2.2054 - val_acc: 0.6000
#
# Epoch 00178: val_acc did not improve from 0.65600
# Epoch 179/200
# 1125/1125 [==============================] - 28s 24ms/step - loss: 0.0559 - acc: 0.9822 - val_loss: 1.6991 - val_acc: 0.5280
#
# Epoch 00179: val_acc did not improve from 0.65600
# Epoch 180/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0484 - acc: 0.9858 - val_loss: 1.6517 - val_acc: 0.5520
#
# Epoch 00180: val_acc did not improve from 0.65600
# Epoch 181/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0442 - acc: 0.9822 - val_loss: 2.0122 - val_acc: 0.5440
#
# Epoch 00181: val_acc did not improve from 0.65600
# Epoch 182/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0208 - acc: 0.9911 - val_loss: 1.7593 - val_acc: 0.6000
#
# Epoch 00182: val_acc did not improve from 0.65600
# Epoch 183/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0190 - acc: 0.9938 - val_loss: 1.6412 - val_acc: 0.6160
#
# Epoch 00183: val_acc did not improve from 0.65600
# Epoch 184/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0229 - acc: 0.9938 - val_loss: 1.7194 - val_acc: 0.6320
#
# Epoch 00184: val_acc did not improve from 0.65600
# Epoch 185/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0372 - acc: 0.9858 - val_loss: 1.1361 - val_acc: 0.5200
#
# Epoch 00185: val_acc did not improve from 0.65600
# Epoch 186/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1601 - acc: 0.9413 - val_loss: 1.9144 - val_acc: 0.6160
#
# Epoch 00186: val_acc did not improve from 0.65600
# Epoch 187/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0734 - acc: 0.9724 - val_loss: 1.3452 - val_acc: 0.4800
#
# Epoch 00187: val_acc did not improve from 0.65600
# Epoch 188/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0458 - acc: 0.9858 - val_loss: 1.2907 - val_acc: 0.5360
#
# Epoch 00188: val_acc did not improve from 0.65600
# Epoch 189/200
# 1125/1125 [==============================] - 29s 25ms/step - loss: 0.0454 - acc: 0.9911 - val_loss: 1.7098 - val_acc: 0.4960
#
# Epoch 00189: val_acc did not improve from 0.65600
# Epoch 190/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0372 - acc: 0.9867 - val_loss: 1.3828 - val_acc: 0.5360
#
# Epoch 00190: val_acc did not improve from 0.65600
# Epoch 191/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1141 - acc: 0.9556 - val_loss: 5.5367 - val_acc: 0.6480
#
# Epoch 00191: val_acc did not improve from 0.65600
# Epoch 192/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1612 - acc: 0.9360 - val_loss: 5.6597 - val_acc: 0.6480
#
# Epoch 00192: val_acc did not improve from 0.65600
# Epoch 193/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.1212 - acc: 0.9591 - val_loss: 3.0277 - val_acc: 0.6480
#
# Epoch 00193: val_acc did not improve from 0.65600
# Epoch 194/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0792 - acc: 0.9680 - val_loss: 1.9351 - val_acc: 0.6240
#
# Epoch 00194: val_acc did not improve from 0.65600
# Epoch 195/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0424 - acc: 0.9884 - val_loss: 1.3141 - val_acc: 0.5680
#
# Epoch 00195: val_acc did not improve from 0.65600
# Epoch 196/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0796 - acc: 0.9778 - val_loss: 1.6390 - val_acc: 0.6000
#
# Epoch 00196: val_acc did not improve from 0.65600
# Epoch 197/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0474 - acc: 0.9876 - val_loss: 1.6604 - val_acc: 0.6000
#
# Epoch 00197: val_acc did not improve from 0.65600
# Epoch 198/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0417 - acc: 0.9884 - val_loss: 1.6429 - val_acc: 0.4720
#
# Epoch 00198: val_acc did not improve from 0.65600
# Epoch 199/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0728 - acc: 0.9760 - val_loss: 3.8188 - val_acc: 0.6560
#
# Epoch 00199: val_acc did not improve from 0.65600
# Epoch 200/200
# 1125/1125 [==============================] - 28s 25ms/step - loss: 0.0420 - acc: 0.9849 - val_loss: 1.5556 - val_acc: 0.5040
#
# Epoch 00200: val_acc did not improve from 0.65600
# 6364.563554807566

# %%
# load best weights
model.load_weights("raw_resnet.hdf5")
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
#model.predict(test_x,batch_size=10)
model.evaluate(tt1,test_y,batch_size=32)
# Out:
# 286/286 [==============================] - 7s 26ms/step
# [1.6369560531802945, 0.6118881114712962]
