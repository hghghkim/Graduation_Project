# %%
from keras import models, layers
from keras import Input
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers, initializers, regularizers, metrics
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import BatchNormalization, Conv3D, Activation, Dense, GlobalAveragePooling3D, MaxPooling3D, ZeroPadding3D, Add
from keras.optimizers import Adam 
import os
#import matplotlib.pyplot as plt
import numpy as np
import math

import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="5,6"

# %%
train_x = np.load('/home/ckwwk/data/germination_data/old_pca(60).npy')

# %%
train_x.shape
# Out:
# (1536, 60, 60, 60, 1)

# %%
t1 = train_x[286:1536,:,:,:]
tt1 = train_x[0:286,:,:,:]

# %%
import pandas as pd

label_df = pd.read_csv("/home/ckwwk/data/germination_data/label/old_germination_label.csv")
label_df.head(5)
# Out:
#    label
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0

# %%
from keras.utils import to_categorical
train_y = label_df[286:1536]
train_y = to_categorical(train_y)

# %%
test_y = label_df[0:286]
test_y = to_categorical(test_y)

# %%
t1 = t1.astype('float32')
tt1 = tt1.astype('float32')

# %%
from keras.backend import tensorflow_backend as K
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
K.set_session(tf.Session(config=config))

# %%
input_tensor = Input(shape=(60, 60, 60,1), dtype='float32', name='input')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1023 22:26:39.989091 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
def conv1_layer(x):    
    #x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv3D(64, (7, 7, 7), strides=2)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding3D(padding=(1,1,1))(x)
 
    return x   
 
    
def conv2_layer(x):         
    x = MaxPooling3D((2, 2, 2), 2)(x)     
 
    shortcut = x
 
    for i in range(3):
        if (i == 0):
            x = Conv3D(64, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(64, (3, 3,3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(256, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(256, (1, 1,1), strides=1, padding='valid')(shortcut)            
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            
            shortcut = x
 
        else:
            x = Conv3D(64, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(64, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(256, (1, 1,1 ), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x
 
 
 
def conv3_layer(x):        
    shortcut = x    
    
    for i in range(4):     
        if(i == 0):            
            x = Conv3D(128, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(128, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(512, (1, 1,1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)    
 
            shortcut = x              
        
        else:
            x = Conv3D(128, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(128, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x
 
 
 
def conv4_layer(x):
    shortcut = x        
  
    for i in range(6):     
        if(i == 0):            
            x = Conv3D(256, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(256, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(1024, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(1024, (1, 1, 1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
 
            shortcut = x               
        
        else:
            x = Conv3D(256, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(256, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(1024, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x
 
 
 
def conv5_layer(x):
    shortcut = x    
  
    for i in range(3):     
        if(i == 0):            
            x = Conv3D(512, (1, 1, 1), strides=(2, 2,2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv3D(512, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv3D(2048, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            shortcut = Conv3D(2048, (1, 1, 1), strides=(2, 2,2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])  
            x = Activation('relu')(x)      
 
            shortcut = x               
        
        else:
            x = Conv3D(512, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv3D(512, (3, 3, 3), strides=(1, 1,1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv3D(2048, (1, 1, 1), strides=(1, 1,1), padding='valid')(x)
            x = BatchNormalization()(x)           
            
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)       
 
            shortcut = x                  
 
    return x

# %%
x = conv1_layer(input_tensor)
x = conv2_layer(x)
x = conv3_layer(x)
x = conv4_layer(x)
x = conv5_layer(x)
 
x = GlobalAveragePooling3D()(x)
output_tensor = Dense(2, activation='softmax')(x)
# Out:
# W1023 22:26:40.042018 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1023 22:26:40.043380 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1023 22:26:40.125928 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.

# %%
model = Model(input_tensor, output_tensor)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 60, 60, 60, 1 0
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 27, 27, 27, 6 22016       input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 27, 6 256         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 27, 27, 27, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding3d_1 (ZeroPadding3D (None, 29, 29, 29, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 14, 14, 14, 6 0           zero_padding3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 14, 14, 14, 6 4160        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 14, 6 256         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 14, 14, 14, 6 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 14, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 14, 14, 14, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 14, 14, 14, 2 16640       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 14, 2 1024        conv3d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 14, 2 1024        conv3d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 14, 2 0           batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 14, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 14, 14, 14, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 14, 6 256         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 14, 14, 14, 6 110656      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 14, 6 256         conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 14, 14, 14, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 14, 2 1024        conv3d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 14, 2 0           batch_normalization_8[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 14, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 14, 14, 14, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 14, 6 256         conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 14, 14, 14, 6 110656      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 14, 6 256         conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 14, 6 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 14, 14, 14, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 14, 2 1024        conv3d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 14, 2 0           batch_normalization_11[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 14, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 7, 7, 7, 128) 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 7, 7, 7, 128) 442496      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 7, 7, 7, 512) 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 7, 7, 7, 512) 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 7, 512) 2048        conv3d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 7, 512) 2048        conv3d_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 7, 512) 0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 7, 512) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 7, 7, 7, 128) 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 7, 7, 7, 128) 442496      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 7, 7, 7, 512) 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 7, 512) 2048        conv3d_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 7, 512) 0           batch_normalization_18[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 7, 512) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 7, 7, 7, 128) 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 7, 7, 7, 128) 442496      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 7, 7, 7, 512) 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 7, 7, 7, 512) 2048        conv3d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 7, 512) 0           batch_normalization_21[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, 7, 7, 512) 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 7, 7, 7, 128) 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 7, 7, 7, 128) 442496      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 7, 7, 7, 128) 512         conv3d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 7, 7, 7, 128) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 7, 7, 7, 512) 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 7, 7, 7, 512) 2048        conv3d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 7, 512) 0           batch_normalization_24[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 7, 7, 7, 512) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 4, 4, 4, 256) 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 4, 4, 4, 1024 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_28[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 4, 1024 0           batch_normalization_27[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 4, 1024 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 4, 4, 4, 256) 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_31[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 4, 1024 0           batch_normalization_31[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 4, 4, 4, 1024 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 4, 4, 4, 256) 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_33[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_34[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4, 4, 4, 1024 0           batch_normalization_34[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 4, 4, 4, 1024 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 4, 4, 4, 256) 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_37[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4, 4, 4, 1024 0           batch_normalization_37[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 4, 1024 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 4, 4, 4, 256) 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv3d_39 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv3d_40 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_40[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 4, 1024 0           batch_normalization_40[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 4, 4, 4, 1024 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv3d_41 (Conv3D)              (None, 4, 4, 4, 256) 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv3d_42 (Conv3D)              (None, 4, 4, 4, 256) 1769728     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 4, 256) 1024        conv3d_42[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 4, 4, 4, 256) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv3d_43 (Conv3D)              (None, 4, 4, 4, 1024 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_43[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4, 4, 4, 1024 0           batch_normalization_43[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 4, 4, 4, 1024 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv3d_44 (Conv3D)              (None, 2, 2, 2, 512) 524800      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv3d_45 (Conv3D)              (None, 2, 2, 2, 512) 7078400     activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv3d_46 (Conv3D)              (None, 2, 2, 2, 2048 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# conv3d_47 (Conv3D)              (None, 2, 2, 2, 2048 2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 2, 2048 8192        conv3d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 2, 2048 8192        conv3d_47[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 2, 2048 0           batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 2, 2, 2, 2048 0           add_14[0][0]
# __________________________________________________________________________________________________
# conv3d_48 (Conv3D)              (None, 2, 2, 2, 512) 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv3d_49 (Conv3D)              (None, 2, 2, 2, 512) 7078400     activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_49[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv3d_50 (Conv3D)              (None, 2, 2, 2, 2048 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 2, 2, 2, 2048 8192        conv3d_50[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 2, 2048 0           batch_normalization_50[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 2, 2, 2, 2048 0           add_15[0][0]
# __________________________________________________________________________________________________
# conv3d_51 (Conv3D)              (None, 2, 2, 2, 512) 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_51[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv3d_52 (Conv3D)              (None, 2, 2, 2, 512) 7078400     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 2, 2, 2, 512) 2048        conv3d_52[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 2, 2, 2, 512) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv3d_53 (Conv3D)              (None, 2, 2, 2, 2048 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 2, 2, 2, 2048 8192        conv3d_53[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 2, 2, 2, 2048 0           batch_normalization_53[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 2, 2, 2, 2048 0           add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_1 (Glo (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            4098        global_average_pooling3d_1[0][0]
# ==================================================================================================
# Total params: 46,238,850
# Trainable params: 46,185,730
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from keras.utils import multi_gpu_model
model = multi_gpu_model(model,gpus=2)
# Out:
# W1023 22:26:45.870901 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.

# %%
adam = Adam(lr=0.0001, decay=1e-06)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
# Out:
# W1023 22:26:59.603790 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
filepath = "pca_resnet.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
tb = keras.callbacks.TensorBoard(log_dir='pca_resnet',histogram_freq=1,)
callbacks_list = [checkpoint,tb]

# %%
import timeit
start = timeit.default_timer()

history = model.fit(x=t1, y=train_y , batch_size=32, epochs=200,validation_split=0.1 ,callbacks=callbacks_list)

stop = timeit.default_timer()
print(stop - start)
# Out:
# W1023 22:27:00.478685 140190306973504 deprecation.py:323] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1125 samples, validate on 125 samples
# W1023 22:27:30.316741 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1120: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# W1023 22:27:30.690366 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W1023 22:27:30.700828 140190306973504 deprecation_wrapper.py:119] From /home/ckwwk/.conda/envs/ck/lib/python3.7/site-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/200
# 1125/1125 [==============================] - 49s 43ms/step - loss: 1.0422 - acc: 0.5200 - val_loss: 1.3520 - val_acc: 0.6480
#
# Epoch 00001: val_acc improved from -inf to 0.64800, saving model to pca_resnet.hdf5
# Epoch 2/200
# 1125/1125 [==============================] - 12s 11ms/step - loss: 0.8570 - acc: 0.5760 - val_loss: 2.2314 - val_acc: 0.6480
#
# Epoch 00002: val_acc did not improve from 0.64800
# Epoch 3/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.5780 - acc: 0.6764 - val_loss: 2.6210 - val_acc: 0.3520
#
# Epoch 00003: val_acc did not improve from 0.64800
# Epoch 4/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.5971 - acc: 0.6942 - val_loss: 2.0767 - val_acc: 0.3920
#
# Epoch 00004: val_acc did not improve from 0.64800
# Epoch 5/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.5058 - acc: 0.7467 - val_loss: 4.4176 - val_acc: 0.3520
#
# Epoch 00005: val_acc did not improve from 0.64800
# Epoch 6/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.4253 - acc: 0.7938 - val_loss: 5.1345 - val_acc: 0.6480
#
# Epoch 00006: val_acc did not improve from 0.64800
# Epoch 7/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.4120 - acc: 0.8444 - val_loss: 3.1515 - val_acc: 0.3440
#
# Epoch 00007: val_acc did not improve from 0.64800
# Epoch 8/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.4453 - acc: 0.8178 - val_loss: 1.7966 - val_acc: 0.6080
#
# Epoch 00008: val_acc did not improve from 0.64800
# Epoch 9/200
# 1125/1125 [==============================] - 12s 11ms/step - loss: 0.5463 - acc: 0.7822 - val_loss: 4.0602 - val_acc: 0.6480
#
# Epoch 00009: val_acc did not improve from 0.64800
# Epoch 10/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2894 - acc: 0.8898 - val_loss: 1.8689 - val_acc: 0.6240
#
# Epoch 00010: val_acc did not improve from 0.64800
# Epoch 11/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2429 - acc: 0.9040 - val_loss: 1.4779 - val_acc: 0.4880
#
# Epoch 00011: val_acc did not improve from 0.64800
# Epoch 12/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2699 - acc: 0.8898 - val_loss: 2.3989 - val_acc: 0.4560
#
# Epoch 00012: val_acc did not improve from 0.64800
# Epoch 13/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2182 - acc: 0.9156 - val_loss: 3.5816 - val_acc: 0.3600
#
# Epoch 00013: val_acc did not improve from 0.64800
# Epoch 14/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.1514 - acc: 0.9413 - val_loss: 3.2607 - val_acc: 0.6480
#
# Epoch 00014: val_acc did not improve from 0.64800
# Epoch 15/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1521 - acc: 0.9360 - val_loss: 1.5638 - val_acc: 0.5520
#
# Epoch 00015: val_acc did not improve from 0.64800
# Epoch 16/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1002 - acc: 0.9609 - val_loss: 1.7964 - val_acc: 0.5520
#
# Epoch 00016: val_acc did not improve from 0.64800
# Epoch 17/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1868 - acc: 0.9280 - val_loss: 4.3172 - val_acc: 0.3520
#
# Epoch 00017: val_acc did not improve from 0.64800
# Epoch 18/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1335 - acc: 0.9467 - val_loss: 2.1571 - val_acc: 0.6160
#
# Epoch 00018: val_acc did not improve from 0.64800
# Epoch 19/200
# 1125/1125 [==============================] - 14s 13ms/step - loss: 0.0913 - acc: 0.9644 - val_loss: 1.6715 - val_acc: 0.4880
#
# Epoch 00019: val_acc did not improve from 0.64800
# Epoch 20/200
# 1125/1125 [==============================] - 14s 12ms/step - loss: 0.0922 - acc: 0.9698 - val_loss: 2.1815 - val_acc: 0.4400
#
# Epoch 00020: val_acc did not improve from 0.64800
# Epoch 21/200
# 1125/1125 [==============================] - 14s 12ms/step - loss: 0.2274 - acc: 0.9173 - val_loss: 2.7648 - val_acc: 0.3920
#
# Epoch 00021: val_acc did not improve from 0.64800
# Epoch 22/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1718 - acc: 0.9440 - val_loss: 1.7657 - val_acc: 0.4720
#
# Epoch 00022: val_acc did not improve from 0.64800
# Epoch 23/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1179 - acc: 0.9511 - val_loss: 2.0689 - val_acc: 0.5200
#
# Epoch 00023: val_acc did not improve from 0.64800
# Epoch 24/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1527 - acc: 0.9493 - val_loss: 2.8486 - val_acc: 0.6480
#
# Epoch 00024: val_acc did not improve from 0.64800
# Epoch 25/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1017 - acc: 0.9733 - val_loss: 2.0206 - val_acc: 0.4560
#
# Epoch 00025: val_acc did not improve from 0.64800
# Epoch 26/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.1624 - acc: 0.9378 - val_loss: 2.5727 - val_acc: 0.5920
#
# Epoch 00026: val_acc did not improve from 0.64800
# Epoch 27/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1135 - acc: 0.9547 - val_loss: 4.2051 - val_acc: 0.6240
#
# Epoch 00027: val_acc did not improve from 0.64800
# Epoch 28/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0853 - acc: 0.9689 - val_loss: 3.3701 - val_acc: 0.3840
#
# Epoch 00028: val_acc did not improve from 0.64800
# Epoch 29/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0910 - acc: 0.9689 - val_loss: 1.5452 - val_acc: 0.6080
#
# Epoch 00029: val_acc did not improve from 0.64800
# Epoch 30/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0550 - acc: 0.9822 - val_loss: 1.7864 - val_acc: 0.5840
#
# Epoch 00030: val_acc did not improve from 0.64800
# Epoch 31/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0782 - acc: 0.9813 - val_loss: 1.5943 - val_acc: 0.5600
#
# Epoch 00031: val_acc did not improve from 0.64800
# Epoch 32/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0704 - acc: 0.9760 - val_loss: 1.5063 - val_acc: 0.5840
#
# Epoch 00032: val_acc did not improve from 0.64800
# Epoch 33/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0825 - acc: 0.9716 - val_loss: 2.4037 - val_acc: 0.6080
#
# Epoch 00033: val_acc did not improve from 0.64800
# Epoch 34/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0589 - acc: 0.9769 - val_loss: 2.4833 - val_acc: 0.5280
#
# Epoch 00034: val_acc did not improve from 0.64800
# Epoch 35/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0267 - acc: 0.9884 - val_loss: 3.3872 - val_acc: 0.6400
#
# Epoch 00035: val_acc did not improve from 0.64800
# Epoch 36/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0745 - acc: 0.9769 - val_loss: 4.0012 - val_acc: 0.5280
#
# Epoch 00036: val_acc did not improve from 0.64800
# Epoch 37/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0854 - acc: 0.9742 - val_loss: 2.1338 - val_acc: 0.5440
#
# Epoch 00037: val_acc did not improve from 0.64800
# Epoch 38/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0869 - acc: 0.9751 - val_loss: 3.3351 - val_acc: 0.5280
#
# Epoch 00038: val_acc did not improve from 0.64800
# Epoch 39/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0602 - acc: 0.9831 - val_loss: 1.9063 - val_acc: 0.4160
#
# Epoch 00039: val_acc did not improve from 0.64800
# Epoch 40/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0307 - acc: 0.9929 - val_loss: 2.5545 - val_acc: 0.5680
#
# Epoch 00040: val_acc did not improve from 0.64800
# Epoch 41/200
# 1125/1125 [==============================] - 10s 9ms/step - loss: 0.0348 - acc: 0.9867 - val_loss: 2.9922 - val_acc: 0.6080
#
# Epoch 00041: val_acc did not improve from 0.64800
# Epoch 42/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.1357 - acc: 0.9529 - val_loss: 2.3556 - val_acc: 0.5440
#
# Epoch 00042: val_acc did not improve from 0.64800
# Epoch 43/200
# 1125/1125 [==============================] - 10s 9ms/step - loss: 0.0978 - acc: 0.9707 - val_loss: 2.3360 - val_acc: 0.6160
#
# Epoch 00043: val_acc did not improve from 0.64800
# Epoch 44/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0732 - acc: 0.9769 - val_loss: 2.0099 - val_acc: 0.4720
#
# Epoch 00044: val_acc did not improve from 0.64800
# Epoch 45/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1851 - acc: 0.9324 - val_loss: 0.9819 - val_acc: 0.5520
#
# Epoch 00045: val_acc did not improve from 0.64800
# Epoch 46/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1199 - acc: 0.9636 - val_loss: 3.0279 - val_acc: 0.5280
#
# Epoch 00046: val_acc did not improve from 0.64800
# Epoch 47/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.1463 - acc: 0.9520 - val_loss: 4.5596 - val_acc: 0.6240
#
# Epoch 00047: val_acc did not improve from 0.64800
# Epoch 48/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1655 - acc: 0.9502 - val_loss: 1.6876 - val_acc: 0.3920
#
# Epoch 00048: val_acc did not improve from 0.64800
# Epoch 49/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0598 - acc: 0.9822 - val_loss: 2.6519 - val_acc: 0.5440
#
# Epoch 00049: val_acc did not improve from 0.64800
# Epoch 50/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0394 - acc: 0.9893 - val_loss: 2.5354 - val_acc: 0.4480
#
# Epoch 00050: val_acc did not improve from 0.64800
# Epoch 51/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0596 - acc: 0.9858 - val_loss: 3.4794 - val_acc: 0.5360
#
# Epoch 00051: val_acc did not improve from 0.64800
# Epoch 52/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0415 - acc: 0.9902 - val_loss: 2.9819 - val_acc: 0.4960
#
# Epoch 00052: val_acc did not improve from 0.64800
# Epoch 53/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0533 - acc: 0.9831 - val_loss: 2.2635 - val_acc: 0.5120
#
# Epoch 00053: val_acc did not improve from 0.64800
# Epoch 54/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0973 - acc: 0.9636 - val_loss: 2.0730 - val_acc: 0.4800
#
# Epoch 00054: val_acc did not improve from 0.64800
# Epoch 55/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0555 - acc: 0.9840 - val_loss: 3.2977 - val_acc: 0.4000
#
# Epoch 00055: val_acc did not improve from 0.64800
# Epoch 56/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0723 - acc: 0.9751 - val_loss: 1.7125 - val_acc: 0.5440
#
# Epoch 00056: val_acc did not improve from 0.64800
# Epoch 57/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0879 - acc: 0.9742 - val_loss: 2.6249 - val_acc: 0.5760
#
# Epoch 00057: val_acc did not improve from 0.64800
# Epoch 58/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1001 - acc: 0.9609 - val_loss: 2.0986 - val_acc: 0.4880
#
# Epoch 00058: val_acc did not improve from 0.64800
# Epoch 59/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0726 - acc: 0.9769 - val_loss: 2.7656 - val_acc: 0.5360
#
# Epoch 00059: val_acc did not improve from 0.64800
# Epoch 60/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0694 - acc: 0.9742 - val_loss: 3.0288 - val_acc: 0.5760
#
# Epoch 00060: val_acc did not improve from 0.64800
# Epoch 61/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0899 - acc: 0.9662 - val_loss: 2.0510 - val_acc: 0.5440
#
# Epoch 00061: val_acc did not improve from 0.64800
# Epoch 62/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0752 - acc: 0.9716 - val_loss: 2.1156 - val_acc: 0.4960
#
# Epoch 00062: val_acc did not improve from 0.64800
# Epoch 63/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0635 - acc: 0.9822 - val_loss: 2.3844 - val_acc: 0.5920
#
# Epoch 00063: val_acc did not improve from 0.64800
# Epoch 64/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0186 - acc: 0.9956 - val_loss: 3.2651 - val_acc: 0.5840
#
# Epoch 00064: val_acc did not improve from 0.64800
# Epoch 65/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0482 - acc: 0.9920 - val_loss: 3.4959 - val_acc: 0.5600
#
# Epoch 00065: val_acc did not improve from 0.64800
# Epoch 66/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0361 - acc: 0.9911 - val_loss: 3.0797 - val_acc: 0.5440
#
# Epoch 00066: val_acc did not improve from 0.64800
# Epoch 67/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0392 - acc: 0.9876 - val_loss: 4.4999 - val_acc: 0.6000
#
# Epoch 00067: val_acc did not improve from 0.64800
# Epoch 68/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0300 - acc: 0.9902 - val_loss: 2.9235 - val_acc: 0.4640
#
# Epoch 00068: val_acc did not improve from 0.64800
# Epoch 69/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0513 - acc: 0.9831 - val_loss: 3.6315 - val_acc: 0.4240
#
# Epoch 00069: val_acc did not improve from 0.64800
# Epoch 70/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0385 - acc: 0.9849 - val_loss: 3.4271 - val_acc: 0.4080
#
# Epoch 00070: val_acc did not improve from 0.64800
# Epoch 71/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0455 - acc: 0.9858 - val_loss: 2.3598 - val_acc: 0.5520
#
# Epoch 00071: val_acc did not improve from 0.64800
# Epoch 72/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0239 - acc: 0.9920 - val_loss: 3.5333 - val_acc: 0.5520
#
# Epoch 00072: val_acc did not improve from 0.64800
# Epoch 73/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0188 - acc: 0.9947 - val_loss: 3.2034 - val_acc: 0.5440
#
# Epoch 00073: val_acc did not improve from 0.64800
# Epoch 74/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0076 - acc: 0.9982 - val_loss: 3.6781 - val_acc: 0.5440
#
# Epoch 00074: val_acc did not improve from 0.64800
# Epoch 75/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0044 - acc: 0.9991 - val_loss: 3.6171 - val_acc: 0.5200
#
# Epoch 00075: val_acc did not improve from 0.64800
# Epoch 76/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0051 - acc: 0.9991 - val_loss: 3.6668 - val_acc: 0.5200
#
# Epoch 00076: val_acc did not improve from 0.64800
# Epoch 77/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0212 - acc: 0.9938 - val_loss: 3.9223 - val_acc: 0.4960
#
# Epoch 00077: val_acc did not improve from 0.64800
# Epoch 78/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0455 - acc: 0.9849 - val_loss: 4.2735 - val_acc: 0.4480
#
# Epoch 00078: val_acc did not improve from 0.64800
# Epoch 79/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0193 - acc: 0.9920 - val_loss: 2.6443 - val_acc: 0.5120
#
# Epoch 00079: val_acc did not improve from 0.64800
# Epoch 80/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0081 - acc: 0.9991 - val_loss: 3.3513 - val_acc: 0.4640
#
# Epoch 00080: val_acc did not improve from 0.64800
# Epoch 81/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0639 - acc: 0.9813 - val_loss: 3.6818 - val_acc: 0.4480
#
# Epoch 00081: val_acc did not improve from 0.64800
# Epoch 82/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0512 - acc: 0.9813 - val_loss: 5.2100 - val_acc: 0.3680
#
# Epoch 00082: val_acc did not improve from 0.64800
# Epoch 83/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.1253 - acc: 0.9671 - val_loss: 3.3533 - val_acc: 0.5280
#
# Epoch 00083: val_acc did not improve from 0.64800
# Epoch 84/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1294 - acc: 0.9573 - val_loss: 3.1003 - val_acc: 0.3680
#
# Epoch 00084: val_acc did not improve from 0.64800
# Epoch 85/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0454 - acc: 0.9840 - val_loss: 2.3526 - val_acc: 0.5360
#
# Epoch 00085: val_acc did not improve from 0.64800
# Epoch 86/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0426 - acc: 0.9902 - val_loss: 2.9874 - val_acc: 0.5280
#
# Epoch 00086: val_acc did not improve from 0.64800
# Epoch 87/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0205 - acc: 0.9938 - val_loss: 2.7923 - val_acc: 0.5520
#
# Epoch 00087: val_acc did not improve from 0.64800
# Epoch 88/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0311 - acc: 0.9920 - val_loss: 2.4375 - val_acc: 0.5280
#
# Epoch 00088: val_acc did not improve from 0.64800
# Epoch 89/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0375 - acc: 0.9911 - val_loss: 3.0257 - val_acc: 0.5680
#
# Epoch 00089: val_acc did not improve from 0.64800
# Epoch 90/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0441 - acc: 0.9884 - val_loss: 2.0737 - val_acc: 0.5040
#
# Epoch 00090: val_acc did not improve from 0.64800
# Epoch 91/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0340 - acc: 0.9911 - val_loss: 3.0994 - val_acc: 0.6320
#
# Epoch 00091: val_acc did not improve from 0.64800
# Epoch 92/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0932 - acc: 0.9751 - val_loss: 2.6562 - val_acc: 0.5920
#
# Epoch 00092: val_acc did not improve from 0.64800
# Epoch 93/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0366 - acc: 0.9876 - val_loss: 2.6686 - val_acc: 0.5840
#
# Epoch 00093: val_acc did not improve from 0.64800
# Epoch 94/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0946 - acc: 0.9733 - val_loss: 3.1534 - val_acc: 0.5280
#
# Epoch 00094: val_acc did not improve from 0.64800
# Epoch 95/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0222 - acc: 0.9947 - val_loss: 2.4279 - val_acc: 0.5440
#
# Epoch 00095: val_acc did not improve from 0.64800
# Epoch 96/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0108 - acc: 0.9973 - val_loss: 2.2452 - val_acc: 0.5920
#
# Epoch 00096: val_acc did not improve from 0.64800
# Epoch 97/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0392 - acc: 0.9876 - val_loss: 2.8994 - val_acc: 0.5840
#
# Epoch 00097: val_acc did not improve from 0.64800
# Epoch 98/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0299 - acc: 0.9911 - val_loss: 3.4130 - val_acc: 0.5680
#
# Epoch 00098: val_acc did not improve from 0.64800
# Epoch 99/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0218 - acc: 0.9938 - val_loss: 3.2261 - val_acc: 0.5760
#
# Epoch 00099: val_acc did not improve from 0.64800
# Epoch 100/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2378 - acc: 0.9120 - val_loss: 5.5315 - val_acc: 0.6240
#
# Epoch 00100: val_acc did not improve from 0.64800
# Epoch 101/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2167 - acc: 0.9253 - val_loss: 3.6409 - val_acc: 0.4720
#
# Epoch 00101: val_acc did not improve from 0.64800
# Epoch 102/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0845 - acc: 0.9716 - val_loss: 3.2878 - val_acc: 0.4960
#
# Epoch 00102: val_acc did not improve from 0.64800
# Epoch 103/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1020 - acc: 0.9733 - val_loss: 3.6492 - val_acc: 0.5280
#
# Epoch 00103: val_acc did not improve from 0.64800
# Epoch 104/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.1093 - acc: 0.9636 - val_loss: 4.3824 - val_acc: 0.5760
#
# Epoch 00104: val_acc did not improve from 0.64800
# Epoch 105/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0345 - acc: 0.9920 - val_loss: 4.3842 - val_acc: 0.5440
#
# Epoch 00105: val_acc did not improve from 0.64800
# Epoch 106/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0861 - acc: 0.9796 - val_loss: 3.4061 - val_acc: 0.5360
#
# Epoch 00106: val_acc did not improve from 0.64800
# Epoch 107/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0644 - acc: 0.9813 - val_loss: 3.2821 - val_acc: 0.5280
#
# Epoch 00107: val_acc did not improve from 0.64800
# Epoch 108/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0301 - acc: 0.9929 - val_loss: 3.7828 - val_acc: 0.5280
#
# Epoch 00108: val_acc did not improve from 0.64800
# Epoch 109/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0187 - acc: 0.9991 - val_loss: 3.0597 - val_acc: 0.5120
#
# Epoch 00109: val_acc did not improve from 0.64800
# Epoch 110/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0156 - acc: 0.9991 - val_loss: 2.9748 - val_acc: 0.5120
#
# Epoch 00110: val_acc did not improve from 0.64800
# Epoch 111/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0299 - acc: 0.9982 - val_loss: 3.0161 - val_acc: 0.5280
#
# Epoch 00111: val_acc did not improve from 0.64800
# Epoch 112/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0353 - acc: 0.9956 - val_loss: 3.3060 - val_acc: 0.5120
#
# Epoch 00112: val_acc did not improve from 0.64800
# Epoch 113/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0983 - acc: 0.9787 - val_loss: 3.9277 - val_acc: 0.4640
#
# Epoch 00113: val_acc did not improve from 0.64800
# Epoch 114/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0824 - acc: 0.9831 - val_loss: 2.3482 - val_acc: 0.5520
#
# Epoch 00114: val_acc did not improve from 0.64800
# Epoch 115/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0583 - acc: 0.9813 - val_loss: 4.9294 - val_acc: 0.5520
#
# Epoch 00115: val_acc did not improve from 0.64800
# Epoch 116/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0244 - acc: 0.9964 - val_loss: 4.0610 - val_acc: 0.5360
#
# Epoch 00116: val_acc did not improve from 0.64800
# Epoch 117/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0475 - acc: 0.9858 - val_loss: 3.5324 - val_acc: 0.5280
#
# Epoch 00117: val_acc did not improve from 0.64800
# Epoch 118/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1368 - acc: 0.9573 - val_loss: 3.8010 - val_acc: 0.5200
#
# Epoch 00118: val_acc did not improve from 0.64800
# Epoch 119/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0859 - acc: 0.9733 - val_loss: 2.9078 - val_acc: 0.4160
#
# Epoch 00119: val_acc did not improve from 0.64800
# Epoch 120/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0396 - acc: 0.9893 - val_loss: 2.1787 - val_acc: 0.4880
#
# Epoch 00120: val_acc did not improve from 0.64800
# Epoch 121/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.0056 - acc: 0.9991 - val_loss: 2.5775 - val_acc: 0.4880
#
# Epoch 00121: val_acc did not improve from 0.64800
# Epoch 122/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0020 - acc: 0.9991 - val_loss: 2.5173 - val_acc: 0.5440
#
# Epoch 00122: val_acc did not improve from 0.64800
# Epoch 123/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0018 - acc: 0.9991 - val_loss: 2.5511 - val_acc: 0.5280
#
# Epoch 00123: val_acc did not improve from 0.64800
# Epoch 124/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0289 - acc: 0.9911 - val_loss: 2.7475 - val_acc: 0.5360
#
# Epoch 00124: val_acc did not improve from 0.64800
# Epoch 125/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0317 - acc: 0.9911 - val_loss: 2.9361 - val_acc: 0.5280
#
# Epoch 00125: val_acc did not improve from 0.64800
# Epoch 126/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0057 - acc: 0.9991 - val_loss: 2.9410 - val_acc: 0.5120
#
# Epoch 00126: val_acc did not improve from 0.64800
# Epoch 127/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0049 - acc: 0.9982 - val_loss: 3.3420 - val_acc: 0.5360
#
# Epoch 00127: val_acc did not improve from 0.64800
# Epoch 128/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0081 - acc: 0.9973 - val_loss: 3.2462 - val_acc: 0.5200
#
# Epoch 00128: val_acc did not improve from 0.64800
# Epoch 129/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0196 - acc: 0.9964 - val_loss: 3.3222 - val_acc: 0.5200
#
# Epoch 00129: val_acc did not improve from 0.64800
# Epoch 130/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0052 - acc: 0.9982 - val_loss: 3.3079 - val_acc: 0.4960
#
# Epoch 00130: val_acc did not improve from 0.64800
# Epoch 131/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 3.3602 - val_acc: 0.5040
#
# Epoch 00131: val_acc did not improve from 0.64800
# Epoch 132/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0141 - acc: 0.9964 - val_loss: 3.7366 - val_acc: 0.5360
#
# Epoch 00132: val_acc did not improve from 0.64800
# Epoch 133/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0404 - acc: 0.9911 - val_loss: 3.6941 - val_acc: 0.5280
#
# Epoch 00133: val_acc did not improve from 0.64800
# Epoch 134/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0121 - acc: 0.9956 - val_loss: 5.5073 - val_acc: 0.5040
#
# Epoch 00134: val_acc did not improve from 0.64800
# Epoch 135/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0079 - acc: 0.9991 - val_loss: 4.2601 - val_acc: 0.5200
#
# Epoch 00135: val_acc did not improve from 0.64800
# Epoch 136/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.2999 - acc: 0.9102 - val_loss: 1.2432 - val_acc: 0.5760
#
# Epoch 00136: val_acc did not improve from 0.64800
# Epoch 137/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.2623 - acc: 0.9058 - val_loss: 2.3788 - val_acc: 0.4960
#
# Epoch 00137: val_acc did not improve from 0.64800
# Epoch 138/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1411 - acc: 0.9556 - val_loss: 4.6573 - val_acc: 0.4800
#
# Epoch 00138: val_acc did not improve from 0.64800
# Epoch 139/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0696 - acc: 0.9778 - val_loss: 3.0693 - val_acc: 0.4320
#
# Epoch 00139: val_acc did not improve from 0.64800
# Epoch 140/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0184 - acc: 0.9964 - val_loss: 2.8495 - val_acc: 0.4560
#
# Epoch 00140: val_acc did not improve from 0.64800
# Epoch 141/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0176 - acc: 0.9956 - val_loss: 2.7898 - val_acc: 0.4720
#
# Epoch 00141: val_acc did not improve from 0.64800
# Epoch 142/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0546 - acc: 0.9822 - val_loss: 3.4937 - val_acc: 0.4240
#
# Epoch 00142: val_acc did not improve from 0.64800
# Epoch 143/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.0144 - acc: 0.9938 - val_loss: 3.2763 - val_acc: 0.5120
#
# Epoch 00143: val_acc did not improve from 0.64800
# Epoch 144/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0087 - acc: 0.9964 - val_loss: 3.0042 - val_acc: 0.5200
#
# Epoch 00144: val_acc did not improve from 0.64800
# Epoch 145/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0093 - acc: 0.9982 - val_loss: 3.2935 - val_acc: 0.5120
#
# Epoch 00145: val_acc did not improve from 0.64800
# Epoch 146/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0073 - acc: 0.9973 - val_loss: 3.3812 - val_acc: 0.5280
#
# Epoch 00146: val_acc did not improve from 0.64800
# Epoch 147/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0118 - acc: 0.9964 - val_loss: 3.6165 - val_acc: 0.4960
#
# Epoch 00147: val_acc did not improve from 0.64800
# Epoch 148/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0072 - acc: 0.9982 - val_loss: 3.6296 - val_acc: 0.4800
#
# Epoch 00148: val_acc did not improve from 0.64800
# Epoch 149/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0029 - acc: 0.9991 - val_loss: 4.1107 - val_acc: 0.4480
#
# Epoch 00149: val_acc did not improve from 0.64800
# Epoch 150/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0179 - acc: 0.9947 - val_loss: 4.2037 - val_acc: 0.4000
#
# Epoch 00150: val_acc did not improve from 0.64800
# Epoch 151/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0484 - acc: 0.9849 - val_loss: 3.8400 - val_acc: 0.4560
#
# Epoch 00151: val_acc did not improve from 0.64800
# Epoch 152/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0405 - acc: 0.9947 - val_loss: 3.1950 - val_acc: 0.4960
#
# Epoch 00152: val_acc did not improve from 0.64800
# Epoch 153/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0196 - acc: 0.9964 - val_loss: 2.3699 - val_acc: 0.4560
#
# Epoch 00153: val_acc did not improve from 0.64800
# Epoch 154/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0112 - acc: 0.9973 - val_loss: 2.8134 - val_acc: 0.5360
#
# Epoch 00154: val_acc did not improve from 0.64800
# Epoch 155/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0206 - acc: 0.9920 - val_loss: 3.0738 - val_acc: 0.4720
#
# Epoch 00155: val_acc did not improve from 0.64800
# Epoch 156/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.3138 - acc: 0.9404 - val_loss: 1.4779 - val_acc: 0.6320
#
# Epoch 00156: val_acc did not improve from 0.64800
# Epoch 157/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1603 - acc: 0.9467 - val_loss: 1.7856 - val_acc: 0.5280
#
# Epoch 00157: val_acc did not improve from 0.64800
# Epoch 158/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1320 - acc: 0.9591 - val_loss: 2.2804 - val_acc: 0.6080
#
# Epoch 00158: val_acc did not improve from 0.64800
# Epoch 159/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0442 - acc: 0.9867 - val_loss: 2.3367 - val_acc: 0.5120
#
# Epoch 00159: val_acc did not improve from 0.64800
# Epoch 160/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0743 - acc: 0.9742 - val_loss: 3.2012 - val_acc: 0.5200
#
# Epoch 00160: val_acc did not improve from 0.64800
# Epoch 161/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0233 - acc: 0.9947 - val_loss: 2.6278 - val_acc: 0.5440
#
# Epoch 00161: val_acc did not improve from 0.64800
# Epoch 162/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0201 - acc: 0.9938 - val_loss: 2.5966 - val_acc: 0.5120
#
# Epoch 00162: val_acc did not improve from 0.64800
# Epoch 163/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0115 - acc: 0.9964 - val_loss: 2.8023 - val_acc: 0.4960
#
# Epoch 00163: val_acc did not improve from 0.64800
# Epoch 164/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0267 - acc: 0.9911 - val_loss: 2.8947 - val_acc: 0.5360
#
# Epoch 00164: val_acc did not improve from 0.64800
# Epoch 165/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0657 - acc: 0.9796 - val_loss: 3.1339 - val_acc: 0.4080
#
# Epoch 00165: val_acc did not improve from 0.64800
# Epoch 166/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0378 - acc: 0.9884 - val_loss: 2.3550 - val_acc: 0.5600
#
# Epoch 00166: val_acc did not improve from 0.64800
# Epoch 167/200
# 1125/1125 [==============================] - 11s 9ms/step - loss: 0.0320 - acc: 0.9876 - val_loss: 1.8217 - val_acc: 0.5360
#
# Epoch 00167: val_acc did not improve from 0.64800
# Epoch 168/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0205 - acc: 0.9911 - val_loss: 2.5412 - val_acc: 0.5520
#
# Epoch 00168: val_acc did not improve from 0.64800
# Epoch 169/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0481 - acc: 0.9893 - val_loss: 2.4045 - val_acc: 0.5520
#
# Epoch 00169: val_acc did not improve from 0.64800
# Epoch 170/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0196 - acc: 0.9938 - val_loss: 4.9182 - val_acc: 0.5600
#
# Epoch 00170: val_acc did not improve from 0.64800
# Epoch 171/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 4.8539 - val_acc: 0.5440
#
# Epoch 00171: val_acc did not improve from 0.64800
# Epoch 172/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 4.5936 - val_acc: 0.5440
#
# Epoch 00172: val_acc did not improve from 0.64800
# Epoch 173/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0370 - acc: 0.9938 - val_loss: 2.3531 - val_acc: 0.4640
#
# Epoch 00173: val_acc did not improve from 0.64800
# Epoch 174/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0733 - acc: 0.9778 - val_loss: 1.7439 - val_acc: 0.5280
#
# Epoch 00174: val_acc did not improve from 0.64800
# Epoch 175/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0311 - acc: 0.9867 - val_loss: 2.3210 - val_acc: 0.5680
#
# Epoch 00175: val_acc did not improve from 0.64800
# Epoch 176/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0097 - acc: 0.9964 - val_loss: 2.2108 - val_acc: 0.5120
#
# Epoch 00176: val_acc did not improve from 0.64800
# Epoch 177/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0175 - acc: 0.9947 - val_loss: 2.4051 - val_acc: 0.4800
#
# Epoch 00177: val_acc did not improve from 0.64800
# Epoch 178/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0080 - acc: 0.9956 - val_loss: 2.3608 - val_acc: 0.4560
#
# Epoch 00178: val_acc did not improve from 0.64800
# Epoch 179/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.2099 - val_acc: 0.4400
#
# Epoch 00179: val_acc did not improve from 0.64800
# Epoch 180/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 8.9282e-04 - acc: 1.0000 - val_loss: 2.3825 - val_acc: 0.4480
#
# Epoch 00180: val_acc did not improve from 0.64800
# Epoch 181/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.6110 - val_acc: 0.4560
#
# Epoch 00181: val_acc did not improve from 0.64800
# Epoch 182/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 7.2016e-04 - acc: 1.0000 - val_loss: 2.6978 - val_acc: 0.4640
#
# Epoch 00182: val_acc did not improve from 0.64800
# Epoch 183/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 7.1690e-04 - acc: 1.0000 - val_loss: 2.7933 - val_acc: 0.4640
#
# Epoch 00183: val_acc did not improve from 0.64800
# Epoch 184/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0026 - acc: 0.9991 - val_loss: 2.8859 - val_acc: 0.4560
#
# Epoch 00184: val_acc did not improve from 0.64800
# Epoch 185/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0020 - acc: 0.9991 - val_loss: 3.0465 - val_acc: 0.4640
#
# Epoch 00185: val_acc did not improve from 0.64800
# Epoch 186/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0058 - acc: 0.9973 - val_loss: 3.5396 - val_acc: 0.4960
#
# Epoch 00186: val_acc did not improve from 0.64800
# Epoch 187/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 3.0688 - val_acc: 0.4880
#
# Epoch 00187: val_acc did not improve from 0.64800
# Epoch 188/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0156 - acc: 0.9982 - val_loss: 3.0428 - val_acc: 0.4880
#
# Epoch 00188: val_acc did not improve from 0.64800
# Epoch 189/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0091 - acc: 0.9982 - val_loss: 3.0493 - val_acc: 0.5040
#
# Epoch 00189: val_acc did not improve from 0.64800
# Epoch 190/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0154 - acc: 0.9991 - val_loss: 3.0828 - val_acc: 0.4800
#
# Epoch 00190: val_acc did not improve from 0.64800
# Epoch 191/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0023 - acc: 0.9982 - val_loss: 3.2662 - val_acc: 0.4400
#
# Epoch 00191: val_acc did not improve from 0.64800
# Epoch 192/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0421 - acc: 0.9920 - val_loss: 3.4496 - val_acc: 0.4960
#
# Epoch 00192: val_acc did not improve from 0.64800
# Epoch 193/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0330 - acc: 0.9893 - val_loss: 3.6514 - val_acc: 0.4560
#
# Epoch 00193: val_acc did not improve from 0.64800
# Epoch 194/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0113 - acc: 0.9956 - val_loss: 3.5167 - val_acc: 0.4560
#
# Epoch 00194: val_acc did not improve from 0.64800
# Epoch 195/200
# 1125/1125 [==============================] - 12s 10ms/step - loss: 0.0032 - acc: 0.9991 - val_loss: 3.5765 - val_acc: 0.4480
#
# Epoch 00195: val_acc did not improve from 0.64800
# Epoch 196/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0069 - acc: 0.9973 - val_loss: 3.6201 - val_acc: 0.4320
#
# Epoch 00196: val_acc did not improve from 0.64800
# Epoch 197/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0070 - acc: 0.9991 - val_loss: 3.8920 - val_acc: 0.4400
#
# Epoch 00197: val_acc did not improve from 0.64800
# Epoch 198/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.0041 - acc: 0.9982 - val_loss: 3.4003 - val_acc: 0.5120
#
# Epoch 00198: val_acc did not improve from 0.64800
# Epoch 199/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.3025 - acc: 0.8960 - val_loss: 3.6149 - val_acc: 0.5040
#
# Epoch 00199: val_acc did not improve from 0.64800
# Epoch 200/200
# 1125/1125 [==============================] - 11s 10ms/step - loss: 0.1675 - acc: 0.9422 - val_loss: 1.1953 - val_acc: 0.5200
#
# Epoch 00200: val_acc did not improve from 0.64800
# 2727.518033585511

# %%
# load best weights
model.load_weights("pca_resnet.hdf5")
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
#model.predict(test_x,batch_size=10)
model.evaluate(tt1,test_y,batch_size=32)
# Out:
# 286/286 [==============================] - 6s 21ms/step
# [0.7001351576585036, 0.7517482546659616]
